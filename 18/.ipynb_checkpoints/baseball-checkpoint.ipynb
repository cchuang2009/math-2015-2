# %%
# %matplotlib inline

import matplotlib.pylab as plt
from scipy import integrate
import numpy  as np
from numpy import sqrt,cos,sin,arctan,pi,exp
from numpy.linalg import norm
from mpl_toolkits.mplot3d import Axes3D
from JSAnimation import IPython_display
from ipywidgets import StaticInteract, RangeWidget,RadioWidget
from IPython.display import display, clear_output
from matplotlib import animation
from matplotlib.patches import Circle

# %% [markdown]
#  The Magnus force models the spin of the ball produced by the kicking action, for instance.  To better understand the spin, see the figure below from the paper.
#
#
#
# First, define the initial position $\vec x_0$, velocity ($\vec v_0$) vectors, the spin ($\vec\omega$) vector, and the gravity ($g$) vector.
#
#
# Parameters in this model include:
#
# - $A$ = cross-sectional area of the ball
# - $M$ = mass of the ball
# - $\rho$ = air density
# - $k = \rho A / (2 M)$
# - $C_d$ = constant of proportionality in the air resistance term
# - $C_m$ = constant of proportionality in the Magnus force (spin) term
#
# <img src="imgs/magnus.png" width=60%>

# %% [markdown]
# <h2>Physics of Baseball</h2>
#
# Generally, a baseball in flight is subject to three distinct forces:
#
# gravity is the for which causes the ball to accelerate vertically downwards at $g=9.8 m/s^2=32.15 ft/s^2$;
# air drag, which impedes the ball's motion through the air;
# Magnus force, which permits the ball to curve laterally.
# Stoke's Law:
#
# Physics of Baseball
#
# Generally, a baseball in flight is subject to three distinct forces:
#
# - Gravity is the force which causes the ball to accelerate vertically downwards at $g=9.8 m/s^2$;
# - air drag is the force which impedes the ball's motion through the air;
# - Magnus force is the force which permits the ball to curve laterally.
#
# <h3>Stoke's Law</h3>
#
# an object which moves  through a viscous fluid is directly proportional to the speed of that object with respect to the fluid.
#
# And a sphere of radius $\mathbb r$, moving with speed $\mathbb v$ through a fluid whose coefficient of viscosity is $\mathbb \eta$, experiences a drag force given by Stokes' law: $$ \mathbb F_D=6\pi \eta r v$$
#
# At velocities sufficiently low for Stokes' law to be valid, air is able to flow smoothly around a passing projectile.

# %% [markdown]
# However, **at higher velocities**, the projectile's motion is too rapid for this to occur. Instead, the projectile effectively knocks the air out of its way. The total mass of air which the projectile comes into contact with per second is $\mathbb \rho\,v\,A$, where
#
# - $\rho$ is the air density,
# - $v$ the projectile speed,
# - and $A$ the projectile's cross-sectional area.
#
# Suppose, as seems reasonable, that the projectile imparts to this air mass a speed $v'$ which is directly proportional to $v$. The rate of momentum gain of the air, which is equal to the drag force acting on the projectile, is approximately
#
# $$\mathbb F_D=\frac{1}{2}C_D(v)\rho A v^2$$
#
# where the drag coefficient, $C_D(v)$, is a dimensionless quantity.

# %% [markdown]
# **Giordano** has developed the following useful formula which quantifies the drag force acting on a baseball:
#
# $$\frac{F_D}{m} = -F(v)\,v\,{\bf \vec v}, $$
#
# where
#
# $$ F(v) = 0.0039 + \frac{0.0058}{1+{\rm exp}[(v-v_d)/{\mit\Delta}]}. $$
#
# Here, $v_d = 35\,{\rm m/s}$ and ${\mit\Delta} = 5\,{\rm m/s}$.

# %% [markdown]
# <h3>Magnus Force</h3>
#
# If we think of drag forces as exerting a sort of pressure on the ball then we can readily appreciate that when the unequal drag forces acting on the ball's upper and lower surfaces are added together there is a component of the resultant force acting upwards. This force -- which is known <font size=+1>$\mathbb{\frac{d x}{d t}}$</font> as the Magnus force, after the German physicist Heinrich Magnus, who first described it in 1853 -- is the dominant spin-dependent force acting on baseballs. The Magnus force can be written
#
# $$ F_M = S(v) \omega \times v, $$
#
# where $\omega$ is the angular velocity vector of the ball. According to Adair and Giordano, it is a fairly good approximation to take
#
# $$ B= \frac{S}{m} =  4.1\times 10^{-4} $$
#
# for baseballs. Note that $B$ is a dimensionless quantity. The magnitude of the Magnus force is about one third of the force due to gravity for typical curveballs.
#
# The equations of motion of a baseball can be written as the following set of coupled first-order o.d.e.s:
#
#
# \begin{align}
#    \vec v &=&\left(\frac{d x}{d t},\frac{d y}{d t},\frac{d z}{d t}\right) &=& (v_x,v_y,v_z)\\
#    \vec \omega &=&  \left(\omega_x,\omega_y,\omega_z \right)   \\
#                &=&  \omega \left(0,\sin\phi,\cos\phi\right)   \\
# \end{align}
#
# There are at least three kinds of forces, gravitation, drag force, and Magnus force, on a flying baseball:
# $$ \vec a = \frac{1}{m}\left(-m (0,0,g)-F_D ||\vec v|| \vec v+S(v)\! \vec\omega \times \vec v \right)$$
#
# To simulate the flight trajectory of baseball, rewrite above into physical quantities in Cartestion coordinates:
#
# \begin{aligned} \frac{d v_x}{d t}&=&- F(v) v v_x + B \omega (v_z\sin \phi - v_y \cos\phi), \\  \frac{d v_y}{d t}&=&- F(v) v v_y + B \omega v_x \cos\phi, \\ \frac{d v_z}{d t}&=&-g- F(v) v v_z - B \omega v_x \sin\phi \end{aligned}
#
# with initial conditions:
#
# $$(x_0,y_0,z_0,v_{x}(0),v_{y}(0),v_{z}(0))=(0,0,0,v_0\cos\theta,0,v_0\sin\theta)$$
#
#
#
# where $v_0$ is the initial speed of the pitch, and $\theta$ is its initial angle of elevation.

# %% [markdown]
# <img src="imgs/magnus-2.png">
#
# The angles  between Magnus Force and  vertical direction, $Z-$axis:
#
# 1. slider: $\phi=0^\circ$;
#
# 2. curveball: $\phi=45^\circ$;
#
# 3. fastball: $\phi=225^\circ$;
#
# 4. screwball: $\phi=135^\circ$;

# %%
#standard distance between pitcher and hitter  
pcd= 60.5  #  60 feet and 6 inches

print 60.5*0.3048, 60.5/(85*5280/60)*1800, 9.81/0.3048
# Out:
# 18.4404 14.5588235294 32.1850393701

# %%
pcd= 60.5  # in feet or  60.5*0.3048m= 18.44 meters

g = 9.81 /0.3048
B=0.00041

x0=np.array([0.,0.,0.])
 
def F(v):
    #v=vector(v)
    return 0.0039+0.0058/(1+exp((norm(v)-35* 5028 /60./60.)/(5.* 5028 /60./60.)))

def V(v): 
    return(v)
        
def G(v): 
    w=np.array([0.,0.,0.])
    #v=vector(v)
    w[0] = -F(v)*norm(v)*v[0] + B*ww*(v[2]*cos(phi) - v[1]*sin(phi))
    w[1] = -F(v)*norm(v)*v[1] + B*ww*v[0]*cos(phi)
    w[2] = -F(v)*norm(v)*v[2] - B*ww*v[0]*sin(phi) -g
    return(w)

# %%
"""
Trajectory of a sliderdelivered by a right-handed pitcher

phi = 0
theta =  pi/180 # one degree 

At time t=0.52sec
speed = 76 mph
"""

ww=1800/60.
v_init = 100 * 5280 /60./60.
phi=0*pi/180
theta = 1*pi/180
v0=np.array([v_init*cos(theta),0,v_init*sin(theta)]) 

t0=0
tn=0.52
dt= 0.0001
n=int(tn/dt) 

t=np.linspace(t0,tn,n+1)
#t=[t0] 
x=[x0] 
v=[v0]

# %%
for i in np.arange(1,n+1): 
    x1=x[i-1]+dt*V(v[i-1]) 
    v1=v[i-1]+dt*G(v[i-1]) 

    x.append(x1) 
    v.append(v1) 
    #t.append(t[i-1]+dt)
#print(x[-2:],v[-1],t[-1])

# %%
xdata0=[ xi[0] for xi in x] 
ydata0=[ xi[1] for xi in x] 
zdata0=[ xi[-1] for xi in x] 
plt.plot(t,ydata0)

# %%
def trajectory(x):
    """
    input x: array for pos1,pos2,pos3
    output x_arr,y_arr,z_arr
    
    """
    xdata0=[ xi[0] for xi in x] 
    ydata0=[ xi[1] for xi in x] 
    zdata0=[ xi[-1] for xi in x] 
    return xdata0,ydata0,zdata0

# %%
xdata0,ydata0,zdata0=trajectory(x)
plt.plot(t,ydata0)

# %%
"""
Trajectory of a screwballball delivered by a right-handed pitcher

phi = 135
theta =  pi/180 # one degree 

At time t=0.52sec
speed = 76 mph
"""

ww=1800/60.
v_init = 100 * 5280 /60./60.
phi=135*pi/180
theta = 1*pi/180
v0=np.array([v_init*cos(theta),0,v_init*sin(theta)]) 

t0=0
tn=0.52
dt= 0.0001
n=int(tn/dt) 
t=np.linspace(t0,tn,n+1)

x=[x0] 
v=[v0]

# %%
for i in np.arange(1,n+1): 
    x1=x[i-1]+dt*V(v[i-1]) 
    v1=v[i-1]+dt*G(v[i-1]) 

    x.append(x1) 
    v.append(v1) 
    #t.append(t[i-1]+dt)

# %%
"""
xdata2=[ xi[0] for xi in x] 
ydata2=[ xi[1] for xi in x] 
zdata2=[ xi[-1] for xi in x] 
"""

xdata2,ydata2,zdata2=trajectory(x)
plt.plot(ydata2,zdata2)

# %%
def trajectoryB(x0,v0,t0=0.,tn=0.52,dt=0.0001,phi=0*pi/180,theta = 1*pi/180):
    xinit=x0;vinit=v0;
    x=[xinit] 
    v=[vinit]
    n=int(tn/dt) 
    t=np.linspace(t0,tn,n+1)
    
    for i in np.arange(1,n+1): 
        x1=x[i-1]+dt*V(v[i-1]) 
        v1=v[i-1]+dt*G(v[i-1]) 

        x.append(x1) 
        v.append(v1)
    xdata0=[ xi[0] for xi in x] 
    ydata0=[ xi[1] for xi in x] 
    
    zdata0=[ xi[-1] for xi in x] 
    return xdata0,ydata0,zdata0

# %%
"""
Trajectory of a slider delivered by a left-handed pitcher

phi = 0
theta = 1* pi/180 # one degree 

At time t=0.52sec
speed = 76 mph
"""

x0=np.array([0.,0.,0.])
v_init = 100 * 5280 /60./60.
phi = 0*pi/180
theta = 1*pi/180
v0=np.array([v_init*cos(theta),0,v_init*sin(theta)]) 

ww = -1800/60.

t=np.linspace(t0,tn,n+1)

# %%
x0
xdata3,ydata3,zdata3=trajectoryB(x0,v0)
plt.plot(ydata3,zdata3,'g-',ydata2,zdata2,'r-',ydata0,zdata0,'b-')
# Out:
# [<matplotlib.lines.Line2D at 0x10c7d8f50>,
#  <matplotlib.lines.Line2D at 0x10c7e8210>,
#  <matplotlib.lines.Line2D at 0x10c7e88d0>]

# %%
plt.plot(t,ydata3)

# %%
"""
Trajectory of a slider delivered by a left-handed pitcher

phi = 0
theta = 1* pi/180 # one degree 

At time t=0.52sec
speed = 76 mph
"""
x0=np.array([0.,0.,0.])
v_init = 100 * 5280 /60./60.
phi = 0*pi/180
theta = 1*pi/180
v0=np.array([v_init*cos(theta),0,v_init*sin(theta)]) 

ww = -1800/60.

t=[t0] 
x=[x0] 
v=[v0]

for i in np.arange(1,n+1): 
    x1=x[i-1]+dt*V(v[i-1]) 
    v1=v[i-1]+dt*G(v[i-1]) 

    x.append(x1) 
    v.append(v1) 
    t.append(t[i-1]+dt)

# %%
#T2=line(x,color="red")
xdata=[ xi[0] for xi in x] 
ydata=[ xi[1] for xi in x] 
zdata=[ xi[-1] for xi in x] 
plt.plot(t,ydata)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')
rect=[[60.4,-0.15,-2.5],[60.4,0.15,-2.5],[60.4,0.15,-2.0] ,[60.4,-0.15,-2.0],[60.4,-0.15,-2.5]]
basex=5*[60.4]
basey=[-0.15,0.15,0.15,-0.15,-0.15]
basez=[-2.5,-2.5,-2.0,-2.0,-2.5]
#ax.set_ylim(-0.5,0.5)
#ax.set_ylim(-0.5,0.5)
ax.set_title("Trajectory")
ax.plot(basex,basey,basez,color="black")
ax.plot(xdata0,ydata0,zdata0, label='Right-handed Slider')
ax.plot(xdata,ydata,zdata, label='Left-handed Slider')
ax.plot(xdata2,ydata2,zdata2, label='Right-handed Screwball')

# Cylinder
rc=0.05
xc=30*np.linspace(-rc, rc, 100)
zc=np.linspace(-3, -0.5, 100)
Xc, Zc=np.meshgrid(xc, zc)
Yc = np.sqrt(rc**2.-(Xc/30.)**2)
rstride = 40
cstride = 20

ax.plot_surface(Xc, Yc, Zc, alpha=0.2, rstride=rstride, cstride=cstride)
ax.plot_surface(Xc, -Yc, Zc, alpha=0.2, rstride=rstride, cstride=cstride)


ax.auto_scale_xyz([-5, 70], [-2, 2], [-3, 1])
ax.view_init(10,20)
ax.pbaspect = [1.0, 1, 1]
ax.legend()

# %%
kinds={'slider': 0.,'curveball': 45.,'fastball':225.,'screwball':135.}
def pitcher(vel,right_hand=True, k='slider', windy=False):
    if right_hand:
       ww=1800/60.
    else:
       ww=-1800/60. 
    if windy:
       v_random=np.random.uniform(0,2.);
    else:
       v_random=0. 
    
    v_init = (vel+v_random) * 5280 /60./60.
    phi=kinds[k]*pi/180
    theta = 1*pi/180
    v0=np.array([v_init*cos(theta),0,v_init*sin(theta)]) 

    t0=0
    tn=0.52
    dt= 0.0001
    n=int(tn/dt) 
    t=np.linspace(t0,tn,n+1)

    x=[x0] 
    v=[v0]
    
    for i in np.arange(1,n+1): 
        x1=x[i-1]+dt*V(v[i-1]) 
        v1=v[i-1]+dt*G(v[i-1]) 

        x.append(x1) 
        v.append(v1)
        
    xdata0=[ xi[0] for xi in x] 
    ydata0=[ xi[1] for xi in x] 
    zdata0=[ xi[-1] for xi in x] 
    return xdata0,ydata0,zdata0

# %%
xdata0,ydata0,zdata0=pitcher(100,True,'slider',)  
plt.plot(t,ydata0)

# %%
def trajectoryBall(*args):
    fig = plt.figure(figsize=(12,8))
    ax = fig.add_subplot(111, projection='3d')
    rect=[[60.4,-0.15,-2.5],[60.4,0.15,-2.5],[60.4,0.15,-2.0] ,[60.4,-0.15,-2.0],[60.4,-0.15,-2.5]]
    basex=5*[60.4]
    basey=[-0.15,0.15,0.15,-0.15,-0.15]
    basez=[-2.5,-2.5,-2.0,-2.0,-2.5]

    ax.set_title(args[3])
    ax.plot(basex,basey,basez,color="red")
    ax.plot(args[0],args[1],args[2],color="blue")

    # Cylinder
    rc=0.05
    xc=30*np.linspace(-rc, rc, 100)
    zc=np.linspace(-3, -0.5, 100)
    Xc, Zc=np.meshgrid(xc, zc)
    Yc = np.sqrt(rc**2.-(Xc/30.)**2)
    rstride = 40;cstride = 20;

    ax.plot_surface(Xc, Yc, Zc, alpha=0.2, rstride=rstride, cstride=cstride)
    ax.plot_surface(Xc, -Yc, Zc, alpha=0.2, rstride=rstride, cstride=cstride)


    ax.auto_scale_xyz([-5, 70], [-2, 2], [-3, 1])
    ax.view_init(10,20)
    ax.pbaspect = [1.0, 1, 1]
    ax.legend()

# %%
xdata1,ydata1,zdata1=pitcher(100,True,'curveball',windy=True)  
xdata2,ydata2,zdata2=pitcher(95,True,'screwball',windy=False)
trajectoryBall(xdata0,ydata0,zdata0,'Trajectory of Right-handed Slider')
trajectoryBall(xdata1,ydata1,zdata1,'Trajectory of Left-handed Curveball')
trajectoryBall(xdata2,ydata2,zdata2,'Trajectory of Right-handed Screwball')
# Out:
# /Users/cch/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# Unlike the other types of pitch we have encountered, knuckleballs are low speed pitches (typically, 65mph) in which the ball is purposely thrown with as little spin as possible. It turns out that knuckleballs are hard to hit because they have unstable trajectories which shift from side to side in a highly unpredictable manner. This is exactly what Watts and Sawyer observed. For the case of a 65mph knuckleball, Giordano has extracted the following useful expression for the lateral force, as a function of angular orientation, $\varphi$, from Watts and Sawyer's data:
#
# $$ \frac{f_y}{m\,g} = G(\varphi) = 0.5\left[\sin(4\varphi) - 0.25\sin(8\varphi) + 0.08\,\sin(12\varphi)- 0.025\,\sin(16\varphi)\right].$$
# The equations of motion of a baseball can be written as the fobr>llowing set of coupled first-order o.d.e.s: $$ $$
# \begin{aligned}
# (\frac{d x}{d t},\frac{d y}{d t},\frac{d z}{d t}) &=& (v_x,v_y,v_z)\\
# \frac{d v_x}{d t}&=&- F(v) v v_x , \\
# \frac{d v_y}{d t}&=&- F(v) v v_y + g G(\varphi) , \\
# \frac{d v_z}{d t}&=&-g- F(v) v v_z \\ \frac{d \varphi}{d t} &=& \omega\end{aligned}

# %%
def Gphi(p):
    return 0.5*( sin(4*p) - 0.25*sin(8*p) + 0.08*sin(12*p) - 0.025*sin(16*p) )

def knuckball(v,p): 
    w=np.array([0,0,0])
    #v=vector(v)
    w[0] = -F(v)*norm(v)*v[0] 
    w[1] = -F(v)*norm(v)*v[1] + g*Gphi(p)
    w[2] = -F(v)*norm(v)*v[2] - g
    dp = ww
    return(w,dp)

# %%
t0=0.69
tn=0.52
dt= 0.0001

ww=40/60.
theta= 4* pi/180.
phi0=-7*pi/180.
v_init = 75 * 5280 /60./60.
x0=np.array([0,0,0])
v0=np.array([v_init*cos(theta),0,v_init*sin(theta)]) 


t=[t0]
x=[x0]
v=[v0]
W=[phi0]
n=int(tn/dt*100/65.) 
for i in np.arange(1,n+1):
    VV,ww1=knuckball(v[i-1],W[i-1])
    x1=x[i-1]+dt*V(v[i-1]) 
    v1=v[i-1]+dt*VV
    ww1=W[i-1]+dt*ww1 

    x.append(x1) 
    v.append(v1)
    W.append(ww1) 
    t.append(t[i-1]+dt)
print x[-1]
# Out:
# [ 75.59471607   0.68531687  -3.93359731]

# %%
xdata=[ xi[0] for xi in x] 
ydata=[ xi[1] for xi in x] 
zdata=[ xi[-1] for xi in x]

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111, projection='3d')
basex=5*[60.4]
basey=[-0.15,0.15,0.15,-0.15,-0.15]
basez=[-2.5,-2.5,-2.0,-2.0,-2.5]
ax.plot(basex,basey,basez,color="black", lw=4)

#ax.plot(xdata,ydata0,zdata0, label='Magnus Effect')
ax.plot(xdata,ydata,zdata, label='Magnus Effect')

# Cylinder
rc=0.05
xc=30*np.linspace(-rc, rc, 100)
zc=np.linspace(-3, -0.5, 100)
Xc, Zc=np.meshgrid(xc, zc)
Yc = np.sqrt(rc**2.-(Xc/30.)**2)
rstride = 40
cstride = 20

ax.plot_surface(Xc, Yc, Zc, alpha=0.2, rstride=rstride, cstride=cstride)
ax.plot_surface(Xc, -Yc, Zc, alpha=0.2, rstride=rstride, cstride=cstride)


ax.auto_scale_xyz([-5, 70], [-2, 2], [-3, 1])
ax.view_init(10,20)
ax.pbaspect = [1.0, 1, 1]

# %%
plt.plot(ydata,zdata)

# %%
t0=0.69
ww=40/60.
theta= 4* pi/180.
phi0=-7*pi/180.
v_init = 60 * 5280 /60./60.
x0=np.array([0,0,0])
vs=-0.
v0=np.array([v_init*cos(theta),vs,v_init*sin(theta)]) 


t=[t0]
x=[x0]
v=[v0]
W=[phi0]
n=int(tn/dt*100/65.) 
for i in np.arange(1,n+1):
    VV,ww1=knuckball(v[i-1],W[i-1])
    x1=x[i-1]+dt*V(v[i-1]) 
    v1=v[i-1]+dt*VV
    ww1=W[i-1]+dt*ww1 

    x.append(x1) 
    v.append(v1)
    W.append(ww1) 
    t.append(t[i-1]+dt)

# %%
xdata1=[ xi[0] for xi in x] 
ydata1=[ xi[1] for xi in x] 
zdata1=[ xi[-1] for xi in x]

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111, projection='3d')

ax.plot(basex,basey,basez,color="black", lw=4)
#ax.plot(xdata,ydata0,zdata0, label='Magnus Effect')
ax.plot(xdata,ydata,zdata, label='Magnus Effect')
ax.plot(xdata1,ydata1,zdata1, label='Magnus Wind')
ax.legend()

# Cylinder
rc=0.05
xc=30*np.linspace(-rc, rc, 100)
zc=np.linspace(-3, -0.5, 100)
Xc, Zc=np.meshgrid(xc, zc)
Yc = np.sqrt(rc**2.-(Xc/30.)**2)
rstride = 40
cstride = 20

ax.plot_surface(Xc, Yc, Zc, alpha=0.2, rstride=rstride, cstride=cstride)
ax.plot_surface(Xc, -Yc, Zc, alpha=0.2, rstride=rstride, cstride=cstride)


ax.auto_scale_xyz([-5, 70], [-2, 2], [-3, 1])
ax.view_init(10,20)
ax.pbaspect = [1.0, 1, 1]

# %%
import matplotlib.pylab as plt
plt.plot(xdata,ydata, label='Magnus Effect')

# %% [markdown]
# $$
# \begin{eqnarray}
#    \frac { d r}{dt}&=&v_r&=&v_0\cos(\theta)\left(1-\frac{a^2}{r^2}\right)\\
#    \frac{d \theta}{dt}&=&\frac{v_\theta}{r}&=&-v_0\sin(\theta)\left(\frac{1}{r}+\frac{a^2}{r^3}\right)+2\frac{\alpha a v_0}{r^2}
# \end{eqnarray}
# $$

# %%
t = np.arange(0, 40, 0.2)
n = 35; 
CI_cart = [[4, .2 * i] for i in range(n)]
CI = map(lambda x: [sqrt(x[0]**2.+x[1]**2.),pi - arctan(x[1]/x[0])], CI_cart)

# %%
CI_cart
# Out:
# [[4, 0.0],
#  [4, 0.2],
#  [4, 0.4],
#  [4, 0.6000000000000001],
#  [4, 0.8],
#  [4, 1.0],
#  [4, 1.2000000000000002],
#  [4, 1.4000000000000001],
#  [4, 1.6],
#  [4, 1.8],
#  [4, 2.0],
#  [4, 2.2],
#  [4, 2.4000000000000004],
#  [4, 2.6],
#  [4, 2.8000000000000003],
#  [4, 3.0],
#  [4, 3.2],
#  [4, 3.4000000000000004],
#  [4, 3.6],
#  [4, 3.8000000000000003],
#  [4, 4.0],
#  [4, 4.2],
#  [4, 4.4],
#  [4, 4.6000000000000005],
#  [4, 4.800000000000001],
#  [4, 5.0],
#  [4, 5.2],
#  [4, 5.4],
#  [4, 5.6000000000000005],
#  [4, 5.800000000000001],
#  [4, 6.0],
#  [4, 6.2],
#  [4, 6.4],
#  [4, 6.6000000000000005],
#  [4, 6.800000000000001]]

# %%
q=plt.Circle((0, 0), radius=1, fill=True, color='red')
patches=[ax.add_patch(q)]

# %%
t=np.linspace(0,40,100)
n = 35; a=1.
CI_cart = [[4, .2 * i] for i in np.arange(n)]
CI = map(lambda x: [sqrt(x[0]**2+x[1]**2),pi - arctan(x[1]/x[0])], CI_cart)
i=1

# %%
fig = plt.figure(figsize=(4, 4))
ax = plt.axes(aspect='equal',xlim=(-4.1, 4.1), ylim=(-4.1, 4.1))
line, = ax.plot([], [], lw=2)

# %%
t=np.linspace(0,40,400)
n = 35; a=1.
CI_cart = [[4, .2 * i] for i in np.arange(n)]
CI = map(lambda x: [sqrt(x[0]**2+x[1]**2),pi - arctan(x[1]/x[0])], CI_cart)
i=1

# %%
plt.figure(figsize=[15,3])
i=0
for alpha in [0.1,0.5,1.,1.25]:
    i+=1
    dX_dt = lambda X, t=0: [cos(X[1])*(1-1/X[0]**2.), -sin(X[1]) * (1/X[0]+1/X[0]**3.) + 2*alpha/X[0]**2.]
    plt.subplot(1,4,i)
    x=np.linspace(0,2*pi,100)
    plt.plot(cos(x),sin(x),color='red',lw=2)

    #ax = plt.axes(aspect='equal',xlim=(-4.1, 4.1), ylim=(-4.1, 4.1))

    for j in range(n):
        X = integrate.odeint(dX_dt, CI[j], t)
        Y = [[u[0]*cos(u[1]), u[0]*sin(u[1])] for u in X]
        Xarr=[y[0] for y in Y]
        Yarr=[y[1] for y in Y]

        plt.xlim(-4.1, 4.1)
        plt.ylim(-4.1, 4.1)
        plt.plot(Xarr,Yarr,  color='blue')
        #ax = plt.axes(aspect='equal',xlim=(-4.1, 4.1), ylim=(-4.1, 4.1))

# %%
def init():
        line.set_data([], [])
        return line
def animate(i):
    alpha=i*0.1
    dX_dt = lambda X, t=0: [cos(X[1])*(1-1/X[0]**2.), -sin(X[1]) * (1/X[0]+1/X[0]**3.) + 2*alpha/X[0]**2.]
    imgs=[]
    for j in range(n):
        X = integrate.odeint(dX_dt, CI[j], t)
        Y = [[u[0]*cos(u[1]), u[0]*sin(u[1])] for u in X]
        Xarr=[y[0] for y in Y]
        Yarr=[y[1] for y in Y]
        img=ax.plot(Xarr,Yarr,color='blue')
        imgs.append(img)
        #append(vector_field,p)

# %%
q = Circle([0, 0], radius=1, fill=True, color='red')
fig = plt.figure(figsize=(4, 4))
ax = plt.axes(aspect='equal',xlim=(-4.1, 4.1), ylim=(-4.1, 4.1))
line, = ax.plot([], [], lw=2)

# %%
animation.FuncAnimation(fig, animate, init_func=init, frames=30, interval=30)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgLGPMSJZYYUVHWQBV">
#     <br>
#     <input id="_anim_sliderLGPMSJZYYUVHWQBV" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animLGPMSJZYYUVHWQBV.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animLGPMSJZYYUVHWQBV.slower()">&#8211;</button>
#     <button onclick="animLGPMSJZYYUVHWQBV.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animLGPMSJZYYUVHWQBV.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animLGPMSJZYYUVHWQBV.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animLGPMSJZYYUVHWQBV.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animLGPMSJZYYUVHWQBV.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animLGPMSJZYYUVHWQBV.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animLGPMSJZYYUVHWQBV.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animLGPMSJZYYUVHWQBV.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectLGPMSJZYYUVHWQBV" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgLGPMSJZYYUVHWQBV";
#     var slider_id = "_anim_sliderLGPMSJZYYUVHWQBV";
#     var loop_select_id = "_anim_loop_selectLGPMSJZYYUVHWQBV";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animLGPMSJZYYUVHWQBV = new Animation(frames, img_id, slider_id, 29, loop_select_id);
#     }, 0);
#   })()
# </script>

# %%
t=np.linspace(0,40,100)
n = 35; a=1.
CI_cart = [[4, .2 * i] for i in np.arange(n)]
CI = map(lambda x: [sqrt(x[0]**2+x[1]**2),pi - arctan(x[1]/x[0])], CI_cart)
i=1

# %%
fig = plt.figure(figsize=(4, 4))
ax = plt.axes(aspect='equal',xlim=(-4.1, 4.1), ylim=(-4.1, 4.1))
line, = ax.plot([], [], lw=2)

# %%
def init():
        line.set_data([], [])
        return line
def animate(i):
    alpha=0.1
    dX_dt = lambda X, t=0: [cos(X[1])*(1-1/X[0]**2.), -sin(X[1]) * (1/X[0]+1/X[0]**3.) + 2*alpha/X[0]**2.]
    imgs=[]
    for j in range(i):
        X = integrate.odeint(dX_dt, CI[j], t)
        Y = [[u[0]*cos(u[1]), u[0]*sin(u[1])] for u in X]
        Xarr=[y[0] for y in Y]
        Yarr=[y[1] for y in Y]
        img=ax.plot(Xarr,Yarr,color='blue')
        imgs.append(img)
        #append(vector_field,p)

# %%
animation.FuncAnimation(fig, animate, init_func=init, frames=30, interval=30)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgCCDIKVQCYBCKEPXK">
#     <br>
#     <input id="_anim_sliderCCDIKVQCYBCKEPXK" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animCCDIKVQCYBCKEPXK.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animCCDIKVQCYBCKEPXK.slower()">&#8211;</button>
#     <button onclick="animCCDIKVQCYBCKEPXK.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCCDIKVQCYBCKEPXK.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCCDIKVQCYBCKEPXK.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCCDIKVQCYBCKEPXK.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animCCDIKVQCYBCKEPXK.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCCDIKVQCYBCKEPXK.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCCDIKVQCYBCKEPXK.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCCDIKVQCYBCKEPXK.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectCCDIKVQCYBCKEPXK" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgCCDIKVQCYBCKEPXK";
#     var slider_id = "_anim_sliderCCDIKVQCYBCKEPXK";
#     var loop_select_id = "_anim_loop_selectCCDIKVQCYBCKEPXK";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animCCDIKVQCYBCKEPXK = new Animation(frames, img_id, slider_id, 29, loop_select_id);
#     }, 0);
#   })()
# </script>

# %%
# %%bash
#
# ipython nbconvert baseball.ipynb
# Out:
# [NbConvertApp] Converting notebook baseball.ipynb to html
# [NbConvertApp] Writing 2726762 bytes to baseball.html
